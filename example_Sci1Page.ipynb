# %% [markdown]
# # Project name---change to the one you are working on

# %% [markdown]
# ----------------------------------

# %% [markdown]
# ## XRD plot

# %%
from XRD_plot import XRD_plot
help(XRD_plot)
# Out:
# Help on function XRD_plot in module XRD_plot:
#
# XRD_plot(filePath='', fileNames=[], labels=[], traceColors=['C0', 'C1', 'C2', 'C3'], Norm='norm', FigName='XRD', xaixsRange=[5, 75])
#     ---This function is used to plot the XRD spectra of mutiple samples---
#     --KeyWords include the following items--
#     1. filePath:--copy the full file path here.
#     2. fileNames: Can specify what you would like to call it
#     3. labels: labels for all the xrd files, the sequence should be correct
#     4. traceColors: defalt value is ['C0','C1','C2','C3']
#     5. Norm = Norm, defalt value is 'norm'. if not specify, will consider as not normalized
#     6. xaixsRange: the range of x axis, default value is [5,75]

# %%
XRD_plot(filePath = 'exemplary_data/XRD/',\
        fileNames = ['sample1.xy','sample2.xy'],\
        labels = ['sample1','sample2'],\
        traceColors = ['C0','C1'],\
        FigName = "trial_XRD_plot",\
        xaixsRange = [5,75])

# %% [markdown]
# ## UV_vis plot

# %%
from UV_vis_plot import UV_vis_plot
help(UV_vis_plot)
# Out:
# Help on function UV_vis_plot in module UV_vis_plot:
#
# UV_vis_plot(filePath='', fileNames=[], labels=[], traceColors=['C0', 'C1', 'C2', 'C3'], FigName='UV_vis.png', xlim=[500, 800], ylim=[0, 4])
#     ---This function is used to plot the XRD spectra of mutiple samples---
#     --KeyWords include the following items--
#     1. filePath:--copy the full file path here.
#     2. fileNames: should conver your file to csv file, and without extension in the file name
#     3. labels: labels for all the xrd files, the sequence should be correct
#     4. traceColors: defalt value is ['C0','C1','C2','C3']
#     5. FigName: give the figure a name
#     6. xlim: the range of x axis, default value is [500,800], change this range as needed
#     7. ylim: defalt range is [0,4], change this range as needed

# %%
UV_vis_plot(filePath = 'exemplary_data/UV-vis/',\
           fileNames = ['sample1','sample2'],\
           labels = ['sample1', 'sample2'],\
           traceColors = ['C0','C1'],\
           FigName = 'trial_UV_plot')

# %% [markdown]
# ## SKPM

# %%
from SKPM_plot import SKPM_plot
help(SKPM_plot)
# Out:
# Help on function SKPM_plot in module SKPM_plot:
#
# SKPM_plot(filePath='', fileName='', scale=4, cmap='magma', clim=[90, 120], FigName='SKPM.png')
#     ---This is for plotting the SKPM image, potential part---
#     1. filePath: complete file path
#     2. fileName: filename without extension as extension .ibw has been attached inside of the code
#     3. cmap = cmap
#     4. scale: image size, i.g. 4um x 4um just type 4, by the way, the defalt pixel in x axis is 256
#        the default scale is set to 1 um
#     5. clim: colorbar range, based on the raw image, change this range
#     6. FigName = FigName

# %%
SKPM_plot(filePath = 'exemplary_data/SKPM/',\
         fileName = 'sample1')
